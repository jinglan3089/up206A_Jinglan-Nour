# %%
# to read and wrangle data
import pandas as pd

# to import data from LA Data portal
from sodapy import Socrata

# to create spatial data
import geopandas as gpd

# for basemaps
import contextily as ctx

# For spatial statistics
import esda
from esda.moran import Moran, Moran_Local

import splot
from splot.esda import moran_scatterplot, plot_moran, lisa_cluster,plot_moran_simulation

import libpysal as lps

# Graphics
import matplotlib.pyplot as plt
import plotly.express as px

# %%
gdf_edu = gpd.read_file('EduLevel.geojson')

# %%
gdf_income=gpd.read_file('Income.geojson')

# %%
gdf_uni=gpd.read_file('Colleges_and_Universities.zip')

# %%
grs= gpd.read_file('GroceryStores.geojson')

# %%
gdf_block = gpd.read_file('acs2019_5yr_B01003_15000US060374028011.geojson')

# %%
gdf_edu = gdf_edu.drop([0])

# %%
gdf_block.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6426 entries, 0 to 6425
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             6426 non-null   object
#  1   name              6426 non-null   object
#  2   B01003001         6426 non-null   float64
#  3   B01003001, Error  6426 non-null   float64
#  4   geometry          6426 non-null   geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 251.1+ KB

# %%
gdf_block = gdf_block[['geoid','B01003001','geometry']]

# rename the columns
gdf_block.columns = ['FIPS','TotalPop','geometry']

# %%
gdf_block.head()
# Out:
#                   FIPS    TotalPop  \
# 0         05000US06037  10081570.0
# 1  15000US060371011101      1688.0
# 2  15000US060371011102      1614.0
# 3  15000US060371011103       981.0
# 4  15000US060371011221      2156.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-118.70339 34.16859, -118.7033...
# 1  MULTIPOLYGON (((-118.29133 34.26008, -118.2913...
# 2  MULTIPOLYGON (((-118.30229 34.25870, -118.3009...
# 3  MULTIPOLYGON (((-118.30080 34.26327, -118.2979...
# 4  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...

# %%
gdf_block.tail()
# Out:
#                      FIPS  TotalPop  \
# 6421  15000US060379800311    1175.0
# 6422  15000US060379800331      16.0
# 6423  15000US060379901000       0.0
# 6424  15000US060379902000       0.0
# 6425  15000US060379903000       0.0
#
#                                                geometry
# 6421  MULTIPOLYGON (((-118.29105 33.75378, -118.2905...
# 6422  MULTIPOLYGON (((-118.24897 33.75590, -118.2470...
# 6423  MULTIPOLYGON (((-118.95114 33.99643, -118.9505...
# 6424  MULTIPOLYGON (((-118.63598 34.03255, -118.6325...
# 6425  MULTIPOLYGON (((-118.47656 33.75038, -118.4661...

# %%
gdf_block=gdf_block.drop(2515)

# %%
gdf_block['FIPS'] = gdf_block['FIPS'].str.replace('15000US','')
gdf_block.tail()
# Out:
#               FIPS  TotalPop  \
# 6421  060379800311    1175.0
# 6422  060379800331      16.0
# 6423  060379901000       0.0
# 6424  060379902000       0.0
# 6425  060379903000       0.0
#
#                                                geometry
# 6421  MULTIPOLYGON (((-118.29105 33.75378, -118.2905...
# 6422  MULTIPOLYGON (((-118.24897 33.75590, -118.2470...
# 6423  MULTIPOLYGON (((-118.95114 33.99643, -118.9505...
# 6424  MULTIPOLYGON (((-118.63598 34.03255, -118.6325...
# 6425  MULTIPOLYGON (((-118.47656 33.75038, -118.4661...

# %%
gdf_block = gdf_block[gdf_block['TotalPop']>100]

# %%
gdf_block = gdf_block.to_crs(epsg=3857)

# %%
# plot it!
fig, ax = plt.subplots(figsize=(12,12))

gdf_block.plot(ax=ax,
         color='black', 
         edgecolor='white',
         lw=0.5,
         alpha=0.4)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
grs.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1377 entries, 0 to 1376
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Store_Name          1377 non-null   object
#  1   Store_Chain         1377 non-null   object
#  2   Street_Number       1377 non-null   object
#  3   Street_Name         1377 non-null   object
#  4   Additional Address  1377 non-null   object
#  5   City                1377 non-null   object
#  6   Zip_Code            1377 non-null   object
#  7   Latitude            1377 non-null   object
#  8   Longitude           1377 non-null   object
#  9   geometry            1377 non-null   geometry
# dtypes: geometry(1), object(9)
# memory usage: 107.7+ KB

# %%
grs.shape
# Out:
# (1377, 10)

# %%
columns_to_keep=['Store_Name',
                 'Store_Chain',
                 'Latitude',
                 'Longitude',
                 'geometry']

# %%
grs= grs[columns_to_keep]

# %%
grs = gpd.GeoDataFrame(grs, 
                         crs='EPSG:4326',
                         geometry=gpd.points_from_xy(grs.Longitude, grs.Latitude))

# %%
grs = grs.to_crs(epsg=3857)

# %%
grs.Longitude = grs.Longitude.astype('float')
grs.Latitude = grs.Latitude.astype('float')

# %%
fig,ax = plt.subplots(figsize=(20,20))

grs.plot(ax=ax,
             color='blue',
             markersize=10, alpha=0.8)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
minx, miny, maxx, maxy = grs.geometry.total_bounds
print(minx)
print(maxx)
print(miny)
print(maxy)
# Out:
# -13229586.772141328
# -13102994.247211216
# 3940847.1884405594
# 4139511.7755141906

# %%
fig, ax = plt.subplots(figsize=(20, 20))

gdf_block.plot(ax=ax,
        color='gray', 
        edgecolor='white',
        alpha=0.5)

grs.plot(ax=ax,
            color='blue',
            markersize=10,
            alpha=0.8)

ax.set_xlim(minx - 1000, maxx + 1000) 
ax.set_ylim(miny - 1000, maxy + 1000)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
join = gpd.sjoin(grs, gdf_block, how='left')
join.head(20)
# Out:
#             Store_Name      Store_Chain  Latitude  Longitude  \
# 0   99 Ranch Market 38  99 Ranch Market  34.09719  -118.1227
# 0   99 Ranch Market 38  99 Ranch Market  34.09719  -118.1227
# 1   99 RANCH MARKET 17  99 Ranch Market  33.87005  -118.0824
# 1   99 RANCH MARKET 17  99 Ranch Market  33.87005  -118.0824
# 2   99 Ranch Market 18  99 Ranch Market  33.99284  -117.9318
# 2   99 Ranch Market 18  99 Ranch Market  33.99284  -117.9318
# 3    99 RANCH MARKET 7  99 Ranch Market  34.12338  -118.0597
# 3    99 RANCH MARKET 7  99 Ranch Market  34.12338  -118.0597
# 4    99 Ranch Market 3  99 Ranch Market  33.99646  -117.8884
# 4    99 Ranch Market 3  99 Ranch Market  33.99646  -117.8884
# 5   99 Ranch Market 13  99 Ranch Market  34.18811  -118.4661
# 5   99 Ranch Market 13  99 Ranch Market  34.18811  -118.4661
# 6    99 RANCH MARKET 6  99 Ranch Market  33.87275  -118.2966
# 6    99 RANCH MARKET 6  99 Ranch Market  33.87275  -118.2966
# 7   99 Ranch Market 12  99 Ranch Market  34.06256  -118.1334
# 7   99 Ranch Market 12  99 Ranch Market  34.06256  -118.1334
# 8  99 Ranch Market 208  99 Ranch Market  34.07961  -118.1015
# 8  99 Ranch Market 208  99 Ranch Market  34.07961  -118.1015
# 9   99 Ranch Market 11  99 Ranch Market  34.06261  -118.0907
# 9   99 Ranch Market 11  99 Ranch Market  34.06261  -118.0907
#
#                             geometry  index_right          FIPS    TotalPop
# 0  POINT (-13149358.815 4041859.746)            0  05000US06037  10081570.0
# 0  POINT (-13149358.815 4041859.746)         3709  060374803022      1427.0
# 1  POINT (-13144872.640 4011366.235)            0  05000US06037  10081570.0
# 1  POINT (-13144872.640 4011366.235)         4925  060375548021      2904.0
# 2  POINT (-13128107.924 4027840.654)            0  05000US06037  10081570.0
# 2  POINT (-13128107.924 4027840.654)         3245  060374086231      3268.0
# 3  POINT (-13142345.687 4045381.002)            0  05000US06037  10081570.0
# 3  POINT (-13142345.687 4045381.002)         3391  060374318001      1990.0
# 4  POINT (-13123276.658 4028326.701)            0  05000US06037  10081570.0
# 4  POINT (-13123276.658 4028326.701)         3222  060374082111       909.0
# 5  POINT (-13187585.928 4054088.658)            0  05000US06037  10081570.0
# 5  POINT (-13187585.928 4054088.658)          551  060371278063      1041.0
# 6  POINT (-13168717.275 4011728.231)            0  05000US06037  10081570.0
# 6  POINT (-13168717.275 4011728.231)         5548  060376032003       966.0
# 7  POINT (-13150549.934 4037205.402)            0  05000US06037  10081570.0
# 7  POINT (-13150549.934 4037205.402)         3802  060374817141      1771.0
# 8  POINT (-13146998.842 4039496.720)            0  05000US06037  10081570.0
# 8  POINT (-13146998.842 4039496.720)         3775  060374814013       883.0
# 9  POINT (-13145796.591 4037212.121)            0  05000US06037  10081570.0
# 9  POINT (-13145796.591 4037212.121)         3846  060374825031      1836.0

# %%
join= join[join.FIPS!='05000US06037']
join.head()
# Out:
#            Store_Name      Store_Chain  Latitude  Longitude  \
# 0  99 Ranch Market 38  99 Ranch Market  34.09719  -118.1227
# 1  99 RANCH MARKET 17  99 Ranch Market  33.87005  -118.0824
# 2  99 Ranch Market 18  99 Ranch Market  33.99284  -117.9318
# 3   99 RANCH MARKET 7  99 Ranch Market  34.12338  -118.0597
# 4   99 Ranch Market 3  99 Ranch Market  33.99646  -117.8884
#
#                             geometry  index_right          FIPS  TotalPop
# 0  POINT (-13149358.815 4041859.746)         3709  060374803022    1427.0
# 1  POINT (-13144872.640 4011366.235)         4925  060375548021    2904.0
# 2  POINT (-13128107.924 4027840.654)         3245  060374086231    3268.0
# 3  POINT (-13142345.687 4045381.002)         3391  060374318001    1990.0
# 4  POINT (-13123276.658 4028326.701)         3222  060374082111     909.0

# %%
grs_joined = join.FIPS.value_counts().rename_axis('FIPS').reset_index(name='store_count')
grs_joined.head()
# Out:
#            FIPS  store_count
# 0  060376511012            8
# 1  060378003242            6
# 2  060374051021            5
# 3  060371133012            5
# 4  060374012021            5

# %%
gdf_block2=gdf_block.merge(grs_joined,on='FIPS')

# %%
gdf_block2.head()
# Out:
#            FIPS  TotalPop                                           geometry  \
# 0  060371013002    1093.0  MULTIPOLYGON (((-13166473.296 4061829.859, -13...
# 1  060371013004     621.0  MULTIPOLYGON (((-13166671.668 4062511.964, -13...
# 2  060371031021     751.0  MULTIPOLYGON (((-13169395.990 4064212.893, -13...
# 3  060371032002    1986.0  MULTIPOLYGON (((-13177225.869 4065687.086, -13...
# 4  060371042031    2960.0  MULTIPOLYGON (((-13181879.469 4066012.016, -13...
#
#    store_count
# 0            4
# 1            1
# 2            1
# 3            1
# 4            1

# %%
fig,ax = plt.subplots(figsize=(15,15))

gdf_block2.plot(ax=ax,
        column='store_count',
        legend=True,
        alpha=0.8,
        cmap='RdYlGn_r',
        scheme='quantiles')

ax.axis('off')
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)
# Out:
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py:238: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py:241: UserWarning: Warning: setting k to 3
#   Warn("Warning: setting k to %d" % k_q, UserWarning)

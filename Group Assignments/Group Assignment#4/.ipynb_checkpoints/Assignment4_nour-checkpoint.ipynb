# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import contextily as ctx
from sodapy import Socrata

# new for data viz
import seaborn as sns

# to explore point patterns
from pointpats import centrography
from matplotlib.patches import Ellipse
import numpy

# %%
gdf=gpd.read_file('Colleges_and_Universities (1).csv')

# %%
gdf.head()
# Out:
#   Colleges_and_Universities (1)      field_2   field_3  \
# 0                             X            Y  OBJECTID
# 1                  -118.2661631  34.03422497     12033
# 2                  -118.4503272  34.22008342     12109
# 3                  -118.1582221  33.91555197     12008
# 4                  -118.0979014   34.1588594     12114
#
#                              field_4 field_5    field_6  \
# 0                             source  ext_id       cat1
# 1  HSIP Freedom CollegesUniversities  108199  Education
# 2  HSIP Freedom CollegesUniversities  377759  Education
# 3  HSIP Freedom CollegesUniversities  444343  Education
# 4  HSIP Freedom CollegesUniversities  108852  Education
#
#                      field_7 field_8    field_9  \
# 0                       cat2    cat3   org_name
# 1  Colleges and Universities          LA County
# 2  Colleges and Universities          LA County
# 3  Colleges and Universities          LA County
# 4  Colleges and Universities          LA County
#
#                                  field_10  ... field_248 field_249 field_250  \
# 0                                    Name  ...
# 1      Abram Friedman Occupational Center  ...
# 2               Adelante Career Institute  ...
# 3                        Advanced College  ...
# 4  American Academy Of Dramatic Arts-West  ...
#
#   field_251 field_252 field_253 field_254 field_255 field_256 geometry
# 0                                                                 None
# 1                                                                 None
# 2                                                                 None
# 3                                                                 None
# 4                                                                 None
#
# [5 rows x 257 columns]

# %%
list(gdf)
# Out:
# ['Colleges_and_Universities (1)',
#  'field_2',
#  'field_3',
#  'field_4',
#  'field_5',
#  'field_6',
#  'field_7',
#  'field_8',
#  'field_9',
#  'field_10',
#  'field_11',
#  'field_12',
#  'field_13',
#  'field_14',
#  'field_15',
#  'field_16',
#  'field_17',
#  'field_18',
#  'field_19',
#  'field_20',
#  'field_21',
#  'field_22',
#  'field_23',
#  'field_24',
#  'field_25',
#  'field_26',
#  'field_27',
#  'field_28',
#  'field_29',
#  'field_30',
#  'field_31',
#  'field_32',
#  'field_33',
#  'field_34',
#  'field_35',
#  'field_36',
#  'field_37',
#  'field_38',
#  'field_39',
#  'field_40',
#  'field_41',
#  'field_42',
#  'field_43',
#  'field_44',
#  'field_45',
#  'field_46',
#  'field_47',
#  'field_48',
#  'field_49',
#  'field_50',
#  'field_51',
#  'field_52',
#  'field_53',
#  'field_54',
#  'field_55',
#  'field_56',
#  'field_57',
#  'field_58',
#  'field_59',
#  'field_60',
#  'field_61',
#  'field_62',
#  'field_63',
#  'field_64',
#  'field_65',
#  'field_66',
#  'field_67',
#  'field_68',
#  'field_69',
#  'field_70',
#  'field_71',
#  'field_72',
#  'field_73',
#  'field_74',
#  'field_75',
#  'field_76',
#  'field_77',
#  'field_78',
#  'field_79',
#  'field_80',
#  'field_81',
#  'field_82',
#  'field_83',
#  'field_84',
#  'field_85',
#  'field_86',
#  'field_87',
#  'field_88',
#  'field_89',
#  'field_90',
#  'field_91',
#  'field_92',
#  'field_93',
#  'field_94',
#  'field_95',
#  'field_96',
#  'field_97',
#  'field_98',
#  'field_99',
#  'field_100',
#  'field_101',
#  'field_102',
#  'field_103',
#  'field_104',
#  'field_105',
#  'field_106',
#  'field_107',
#  'field_108',
#  'field_109',
#  'field_110',
#  'field_111',
#  'field_112',
#  'field_113',
#  'field_114',
#  'field_115',
#  'field_116',
#  'field_117',
#  'field_118',
#  'field_119',
#  'field_120',
#  'field_121',
#  'field_122',
#  'field_123',
#  'field_124',
#  'field_125',
#  'field_126',
#  'field_127',
#  'field_128',
#  'field_129',
#  'field_130',
#  'field_131',
#  'field_132',
#  'field_133',
#  'field_134',
#  'field_135',
#  'field_136',
#  'field_137',
#  'field_138',
#  'field_139',
#  'field_140',
#  'field_141',
#  'field_142',
#  'field_143',
#  'field_144',
#  'field_145',
#  'field_146',
#  'field_147',
#  'field_148',
#  'field_149',
#  'field_150',
#  'field_151',
#  'field_152',
#  'field_153',
#  'field_154',
#  'field_155',
#  'field_156',
#  'field_157',
#  'field_158',
#  'field_159',
#  'field_160',
#  'field_161',
#  'field_162',
#  'field_163',
#  'field_164',
#  'field_165',
#  'field_166',
#  'field_167',
#  'field_168',
#  'field_169',
#  'field_170',
#  'field_171',
#  'field_172',
#  'field_173',
#  'field_174',
#  'field_175',
#  'field_176',
#  'field_177',
#  'field_178',
#  'field_179',
#  'field_180',
#  'field_181',
#  'field_182',
#  'field_183',
#  'field_184',
#  'field_185',
#  'field_186',
#  'field_187',
#  'field_188',
#  'field_189',
#  'field_190',
#  'field_191',
#  'field_192',
#  'field_193',
#  'field_194',
#  'field_195',
#  'field_196',
#  'field_197',
#  'field_198',
#  'field_199',
#  'field_200',
#  'field_201',
#  'field_202',
#  'field_203',
#  'field_204',
#  'field_205',
#  'field_206',
#  'field_207',
#  'field_208',
#  'field_209',
#  'field_210',
#  'field_211',
#  'field_212',
#  'field_213',
#  'field_214',
#  'field_215',
#  'field_216',
#  'field_217',
#  'field_218',
#  'field_219',
#  'field_220',
#  'field_221',
#  'field_222',
#  'field_223',
#  'field_224',
#  'field_225',
#  'field_226',
#  'field_227',
#  'field_228',
#  'field_229',
#  'field_230',
#  'field_231',
#  'field_232',
#  'field_233',
#  'field_234',
#  'field_235',
#  'field_236',
#  'field_237',
#  'field_238',
#  'field_239',
#  'field_240',
#  'field_241',
#  'field_242',
#  'field_243',
#  'field_244',
#  'field_245',
#  'field_246',
#  'field_247',
#  'field_248',
#  'field_249',
#  'field_250',
#  'field_251',
#  'field_252',
#  'field_253',
#  'field_254',
#  'field_255',
#  'field_256',
#  'geometry']

# %%
columns_to_keep =['Colleges_and_Universities (1)',
 'field_2',
 'field_3',
 'field_4',
 'field_9',
 'field_10',
 'field_11',
 'field_14',
 'field_15',
 'geometry']

# %%
gdf=gdf[columns_to_keep]

# %%
gdf.head()
# Out:
#   Colleges_and_Universities (1)      field_2   field_3  \
# 0                             X            Y  OBJECTID
# 1                  -118.2661631  34.03422497     12033
# 2                  -118.4503272  34.22008342     12109
# 3                  -118.1582221  33.91555197     12008
# 4                  -118.0979014   34.1588594     12114
#
#                              field_4    field_9  \
# 0                             source   org_name
# 1  HSIP Freedom CollegesUniversities  LA County
# 2  HSIP Freedom CollegesUniversities  LA County
# 3  HSIP Freedom CollegesUniversities  LA County
# 4  HSIP Freedom CollegesUniversities  LA County
#
#                                  field_10    field_11     field_14 field_15  \
# 0                                    Name        type         city    state
# 1      Abram Friedman Occupational Center      Public  Los Angeles       CA
# 2               Adelante Career Institute  For Profit     Van Nuys       CA
# 3                        Advanced College  For Profit   South Gate       CA
# 4  American Academy Of Dramatic Arts-West     Private  Los Angeles       CA
#
#   geometry
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None

# %%
gdf = gdf.drop([0])

# %%
gdf.head()
# Out:
#   Colleges_and_Universities (1)      field_2 field_3  \
# 1                  -118.2661631  34.03422497   12033
# 2                  -118.4503272  34.22008342   12109
# 3                  -118.1582221  33.91555197   12008
# 4                  -118.0979014   34.1588594   12114
# 5                  -118.0986221  33.87113085   12126
#
#                              field_4    field_9  \
# 1  HSIP Freedom CollegesUniversities  LA County
# 2  HSIP Freedom CollegesUniversities  LA County
# 3  HSIP Freedom CollegesUniversities  LA County
# 4  HSIP Freedom CollegesUniversities  LA County
# 5  HSIP Freedom CollegesUniversities  LA County
#
#                                  field_10    field_11     field_14 field_15  \
# 1      Abram Friedman Occupational Center      Public  Los Angeles       CA
# 2               Adelante Career Institute  For Profit     Van Nuys       CA
# 3                        Advanced College  For Profit   South Gate       CA
# 4  American Academy Of Dramatic Arts-West     Private  Los Angeles       CA
# 5                 American Auto Institute  For Profit     Cerritos       CA
#
#   geometry
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None

# %%
gdf.columns
# Out:
# Index(['Colleges_and_Universities (1)', 'field_2', 'field_3', 'field_4',
#        'field_9', 'field_10', 'field_11', 'field_14', 'field_15', 'geometry'],
#       dtype='object')

# %%
gdf.rename(columns={'Colleges_and_Universities (1)': 'X', 'field_2': 'Y','field_10':'Name','field_11':'SType'}, inplace=True)

# %%
gdf.columns
# Out:
# Index(['X', 'Y', 'field_3', 'field_4', 'field_9', 'Name', 'SType', 'field_14',
#        'field_15', 'geometry'],
#       dtype='object')

# %%
print(gdf['X'].head())

print(gdf['Y'].head())
# Out:
# 1    -118.2661631
# 2    -118.4503272
# 3    -118.1582221
# 4    -118.0979014
# 5    -118.0986221
# Name: X, dtype: object
# 1    34.03422497
# 2    34.22008342
# 3    33.91555197
# 4     34.1588594
# 5    33.87113085
# Name: Y, dtype: object

# %%
utm18nCRS = gdf.crs
utm18nCRS

# %%
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.X, gdf.Y), crs=utm18nCRS)

# %%
gdf.crs

# %%
fig, ax = plt.subplots()
gdf.plot(ax=ax)
plt.title("School Locations")
plt.show()

# %%
gdf.geometry
# Out:
# 1      POINT (-118.26616 34.03422)
# 2      POINT (-118.45033 34.22008)
# 3      POINT (-118.15822 33.91555)
# 4      POINT (-118.09790 34.15886)
# 5      POINT (-118.09862 33.87113)
#                   ...
# 156    POINT (-118.34069 34.20923)
# 157    POINT (-118.30914 34.07882)
# 158    POINT (-118.22022 33.79099)
# 159    POINT (-118.34663 34.08529)
# 160    POINT (-118.44295 33.99290)
# Name: geometry, Length: 160, dtype: geometry

# %%
gdf = gpd.GeoDataFrame(gdf, 
                     crs='EPSG:4326',
                     geometry=gpd.points_from_xy(gdf.X, gdf.Y))

# %%
gdf = gdf[gdf.X!=0]

# %%
gdf.plot(figsize=(12,12),
             markersize=1)
# Out:
# <AxesSubplot:>

# %%
gdf.sample(10)
# Out:
#                 X            Y field_3                            field_4  \
# 51   -118.2720881  34.05623197   11976  HSIP Freedom CollegesUniversities
# 72   -118.3075701  34.09808697   11992  HSIP Freedom CollegesUniversities
# 12   -118.1843711  34.67498697   58290                                211
# 68   -117.9602661  34.01002297   11974  HSIP Freedom CollegesUniversities
# 132  -118.5734388  34.40583105   58194                                211
# 87   -118.2121351  34.06215697   12053  HSIP Freedom CollegesUniversities
# 67   -118.3288701  34.09001497   12023  HSIP Freedom CollegesUniversities
# 125   -117.705939  34.10340844   12129  HSIP Freedom CollegesUniversities
# 156  -118.3406919  34.20922628   12131  HSIP Freedom CollegesUniversities
# 38   -118.0974731  33.88742597   57316                                211
#
#               field_9                                               Name  \
# 51          LA County                     Diversified Language Institute
# 72          LA County                                       Icdc College
# 12        www.avc.edu         Antelope Valley Community College District
# 68          LA County  Hacienda La Puente Unified School District-Adu...
# 132   www.canyons.edu           Santa Clarita Community College District
# 87          LA County  Los Angeles County College Of Nursing And Alli...
# 67          LA County                    Gnomon School Of Visual Effects
# 125         LA County                                     Pitzer College
# 156         LA County                                Woodbury University
# 38   www.cerritos.edu                Cerritos Community College District
#
#           SType          field_14 field_15                     geometry
# 51   For Profit       Los Angeles       CA  POINT (-118.27209 34.05623)
# 72   For Profit       Los Angeles       CA  POINT (-118.30757 34.09809)
# 12       Public         Lancaster       CA  POINT (-118.18437 34.67499)
# 68      Private  City Of Industry       CA  POINT (-117.96027 34.01002)
# 132      Public     Santa Clarita       CA  POINT (-118.57344 34.40583)
# 87       Public       Los Angeles       CA  POINT (-118.21214 34.06216)
# 67   For Profit         Hollywood       CA  POINT (-118.32887 34.09001)
# 125     Private         Claremont       CA  POINT (-117.70594 34.10341)
# 156     Private           Burbank       CA  POINT (-118.34069 34.20923)
# 38       Public           Norwalk       CA  POINT (-118.09747 33.88743)

# %%
gdf.rename(columns={'field_3': 'objectid', 'field_4': 'college','field_9':'county','field_14':'city','field_15':'state'}, inplace=True)

# %%
gdf.head()
# Out:
#               X            Y objectid                            college  \
# 1  -118.2661631  34.03422497    12033  HSIP Freedom CollegesUniversities
# 2  -118.4503272  34.22008342    12109  HSIP Freedom CollegesUniversities
# 3  -118.1582221  33.91555197    12008  HSIP Freedom CollegesUniversities
# 4  -118.0979014   34.1588594    12114  HSIP Freedom CollegesUniversities
# 5  -118.0986221  33.87113085    12126  HSIP Freedom CollegesUniversities
#
#       county                                    Name       SType         city  \
# 1  LA County      Abram Friedman Occupational Center      Public  Los Angeles
# 2  LA County               Adelante Career Institute  For Profit     Van Nuys
# 3  LA County                        Advanced College  For Profit   South Gate
# 4  LA County  American Academy Of Dramatic Arts-West     Private  Los Angeles
# 5  LA County                 American Auto Institute  For Profit     Cerritos
#
#   state                     geometry
# 1    CA  POINT (-118.26616 34.03422)
# 2    CA  POINT (-118.45033 34.22008)
# 3    CA  POINT (-118.15822 33.91555)
# 4    CA  POINT (-118.09790 34.15886)
# 5    CA  POINT (-118.09862 33.87113)

# %%
SType_count = gdf.SType.value_counts().head(10).index.tolist()
SType_count
# Out:
# ['For Profit', 'Private', 'Public']

# %%
type_count= gdf['SType'].value_counts()

# %%
type_count=type_count.reset_index()
type_count
# Out:
#         index  SType
# 0  For Profit     65
# 1     Private     61
# 2      Public     34

# %%
gdf[gdf.SType == 'Private'].head(10)
# Out:
#                X            Y objectid                            college  \
# 4   -118.0979014   34.1588594    12114  HSIP Freedom CollegesUniversities
# 7   -118.3093841  34.10712497    12034  HSIP Freedom CollegesUniversities
# 9   -118.4717091  34.12925797    12049  HSIP Freedom CollegesUniversities
# 14  -118.3846511  33.98763997    11963  HSIP Freedom CollegesUniversities
# 16  -118.1869011  34.17084397    12035  HSIP Freedom CollegesUniversities
# 19  -117.8879501   34.1308651    12153  HSIP Freedom CollegesUniversities
# 21  -118.0173424  33.90482309    12135  HSIP Freedom CollegesUniversities
# 26  -118.1257399   34.1392753    12148  HSIP Freedom CollegesUniversities
# 27  -118.5673032  34.39333701    12127  HSIP Freedom CollegesUniversities
# 37  -118.4487061  34.19534297    12039  HSIP Freedom CollegesUniversities
#
#        county                                    Name    SType         city  \
# 4   LA County  American Academy Of Dramatic Arts-West  Private  Los Angeles
# 7   LA County    American Film Institute Conservatory  Private  Los Angeles
# 9   LA County              American Jewish University  Private  Los Angeles
# 14  LA County   Antioch University-Los Angeles Branch  Private  Culver City
# 16  LA County            Art Center College Of Design  Private     Pasadena
# 19  LA County                Azusa Pacific University  Private        Azusa
# 21  LA County                        Biola University  Private    La Mirada
# 26  LA County      California Institute Of Technology  Private     Pasadena
# 27  LA County        California Institute Of The Arts  Private     Valencia
# 37  LA County              Casa Loma College-Van Nuys  Private     Van Nuys
#
#    state                     geometry
# 4     CA  POINT (-118.09790 34.15886)
# 7     CA  POINT (-118.30938 34.10712)
# 9     CA  POINT (-118.47171 34.12926)
# 14    CA  POINT (-118.38465 33.98764)
# 16    CA  POINT (-118.18690 34.17084)
# 19    CA  POINT (-117.88795 34.13087)
# 21    CA  POINT (-118.01734 33.90482)
# 26    CA  POINT (-118.12574 34.13928)
# 27    CA  POINT (-118.56730 34.39334)
# 37    CA  POINT (-118.44871 34.19534)

# %%
SType = 'Private'

# map
ax = gdf[gdf.SType == SType].plot(figsize=(15,15), markersize=10)

# title (including count)
ax.set_title(SType + ' (' + str(gdf[gdf.SType == SType].shape[0]) + ' count)')

# axis
ax.axis('off')

# basemap
ctx.add_basemap(ax,
                crs='epsg:4326', # surprise! You can change the crs here!
                source=ctx.providers.CartoDB.Positron)

# %%
def SType_by(SType='Public'):
    
    # map
    ax = gdf[gdf.SType == SType].plot(figsize=(9,9), markersize=10)
    
    # axis
    ax.axis('off')
    
    # title (including count)
    ax.set_title(SType + ' (' + str(gdf[gdf.SType == SType].shape[0]) + ' count)')

    # basemap
    ctx.add_basemap(ax,
                    crs='epsg:4326', # surprise! You can change the crs here!
                    source=ctx.providers.CartoDB.Positron)

# %%
for SType in SType_count:
    SType_by(SType = SType)

# %%
gdf['x'] = gdf.geometry.x
gdf['y'] = gdf.geometry.y

# %%
gdf.head()
# Out:
#               X            Y objectid                            college  \
# 1  -118.2661631  34.03422497    12033  HSIP Freedom CollegesUniversities
# 2  -118.4503272  34.22008342    12109  HSIP Freedom CollegesUniversities
# 3  -118.1582221  33.91555197    12008  HSIP Freedom CollegesUniversities
# 4  -118.0979014   34.1588594    12114  HSIP Freedom CollegesUniversities
# 5  -118.0986221  33.87113085    12126  HSIP Freedom CollegesUniversities
#
#       county                                    Name       SType         city  \
# 1  LA County      Abram Friedman Occupational Center      Public  Los Angeles
# 2  LA County               Adelante Career Institute  For Profit     Van Nuys
# 3  LA County                        Advanced College  For Profit   South Gate
# 4  LA County  American Academy Of Dramatic Arts-West     Private  Los Angeles
# 5  LA County                 American Auto Institute  For Profit     Cerritos
#
#   state                     geometry           x          y
# 1    CA  POINT (-118.26616 34.03422) -118.266163  34.034225
# 2    CA  POINT (-118.45033 34.22008) -118.450327  34.220083
# 3    CA  POINT (-118.15822 33.91555) -118.158222  33.915552
# 4    CA  POINT (-118.09790 34.15886) -118.097901  34.158859
# 5    CA  POINT (-118.09862 33.87113) -118.098622  33.871131

# %%
sns.relplot(data=gdf,
            x='x', 
            y='y',
            s=3, # size of point
            height=8 # size of plot
           )

# %%
sns.set_style('darkgrid')

# scatterplot 
sns.relplot(data=gdf,
            x='x', 
            y='y',
            s=3,
            height=8)

# %%
def sns_styles(style='darkgrid'):
    # seaborn comes with themes to make them prettier
    sns.set_style(style)

    # scatterplot 
    sns.relplot(data=gdf,
                x='x', 
                y='y',
                s=3,
                height=8)

# %%
for style in ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']:
    sns_styles(style = style)

# %%
color_list=['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r']

# %%
sns.relplot(data=gdf,
            x='x', 
            y='y',
            hue='city',
            palette='tab20',
            s=5,
            height=8)

# %%
sns.relplot(data=gdf,
            x='x', 
            y='y',
            hue='SType',
            palette='tab20',
            s=5,
            height=8)

# %%
sns.relplot(data=gdf[gdf['city']=='Los Angeles'],
            x='x', 
            y='y')

# %%
sns.relplot(data=gdf[gdf['city']=='Los Angeles'],
            x='x', 
            y='y',
            hue='SType')

# %%
sns.set_style('white')
g = sns.jointplot(data = gdf,
                  x='x', 
                  y='y',
                  s=10,
                  height=8 
                 )

ctx.add_basemap(g.ax_joint,
                crs='epsg:4326')

# %%
f, ax = plt.subplots(figsize=(12, 9))

hb = ax.hexbin(
    x = gdf['x'], 
    y = gdf['y'],
    gridsize=50, 
    linewidths=1,
    alpha=0.5, 
    mincnt=1, 
    cmap='viridis'
)


ctx.add_basemap(
    ax, 
    crs='epsg:4326',
    source=ctx.providers.CartoDB.Positron
)


plt.colorbar(hb)


ax.axis('off')
# Out:
# (-118.75776379610191, -117.65585210389808, 33.687485772, 34.724663408)

# %%
gdf_SType = gdf[gdf.SType.isin(['Private','Public','For Profit'])]

# %%
g = sns.jointplot(data = gdf_SType,
                  x='x', 
                  y='y',
                  hue='SType',
                  s=10,
                  height=15 
                 )

g.ax_joint.set_axis_off()


ctx.add_basemap(g.ax_joint,
                crs='epsg:4326')
